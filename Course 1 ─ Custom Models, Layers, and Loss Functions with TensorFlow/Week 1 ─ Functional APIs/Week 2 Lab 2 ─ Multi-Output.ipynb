# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 912us/sample - loss: 252.3004 - y1_output_loss: 115.6123 - y2_output_loss: 134.6862 - y1_output_root_mean_squared_error: 10.7990 - y2_output_root_mean_squared_error: 11.6483 - val_loss: 80.3689 - val_y1_output_loss: 19.8871 - val_y2_output_loss: 60.7319 - val_y1_output_root_mean_squared_error: 4.4873 - val_y2_output_root_mean_squared_error: 7.7610
# Epoch 2/500
# 614/614 [==============================] - 0s 144us/sample - loss: 33.0453 - y1_output_loss: 12.7020 - y2_output_loss: 20.5233 - y1_output_root_mean_squared_error: 3.5365 - y2_output_root_mean_squared_error: 4.5320 - val_loss: 47.3150 - val_y1_output_loss: 14.4683 - val_y2_output_loss: 33.7757 - val_y1_output_root_mean_squared_error: 3.8108 - val_y2_output_root_mean_squared_error: 5.7265
# Epoch 3/500
# 614/614 [==============================] - 0s 136us/sample - loss: 29.5091 - y1_output_loss: 11.0060 - y2_output_loss: 18.5058 - y1_output_root_mean_squared_error: 3.3210 - y2_output_root_mean_squared_error: 4.2988 - val_loss: 45.3369 - val_y1_output_loss: 14.0638 - val_y2_output_loss: 31.5990 - val_y1_output_root_mean_squared_error: 3.7787 - val_y2_output_root_mean_squared_error: 5.5730
# Epoch 4/500
# 614/614 [==============================] - 0s 129us/sample - loss: 23.9662 - y1_output_loss: 9.6487 - y2_output_loss: 14.4100 - y1_output_root_mean_squared_error: 3.0964 - y2_output_root_mean_squared_error: 3.7919 - val_loss: 45.6305 - val_y1_output_loss: 14.3685 - val_y2_output_loss: 30.9669 - val_y1_output_root_mean_squared_error: 3.8128 - val_y2_output_root_mean_squared_error: 5.5761
# Epoch 5/500
# 614/614 [==============================] - 0s 128us/sample - loss: 22.5272 - y1_output_loss: 8.7952 - y2_output_loss: 13.5511 - y1_output_root_mean_squared_error: 2.9775 - y2_output_root_mean_squared_error: 3.6962 - val_loss: 20.3050 - val_y1_output_loss: 9.2651 - val_y2_output_loss: 10.4416 - val_y1_output_root_mean_squared_error: 3.0919 - val_y2_output_root_mean_squared_error: 3.2780
# Epoch 6/500
# 614/614 [==============================] - 0s 128us/sample - loss: 19.6148 - y1_output_loss: 8.1647 - y2_output_loss: 11.2842 - y1_output_root_mean_squared_error: 2.8703 - y2_output_root_mean_squared_error: 3.3729 - val_loss: 18.0459 - val_y1_output_loss: 8.3149 - val_y2_output_loss: 9.1237 - val_y1_output_root_mean_squared_error: 2.9288 - val_y2_output_root_mean_squared_error: 3.0770
# Epoch 7/500
# 614/614 [==============================] - 0s 128us/sample - loss: 24.5470 - y1_output_loss: 8.8922 - y2_output_loss: 15.4827 - y1_output_root_mean_squared_error: 2.9949 - y2_output_root_mean_squared_error: 3.9469 - val_loss: 33.6209 - val_y1_output_loss: 11.4769 - val_y2_output_loss: 21.4575 - val_y1_output_root_mean_squared_error: 3.4449 - val_y2_output_root_mean_squared_error: 4.6641
# Epoch 8/500
# 614/614 [==============================] - 0s 126us/sample - loss: 24.8827 - y1_output_loss: 9.1265 - y2_output_loss: 15.6007 - y1_output_root_mean_squared_error: 3.0259 - y2_output_root_mean_squared_error: 3.9656 - val_loss: 20.7145 - val_y1_output_loss: 9.2622 - val_y2_output_loss: 10.7260 - val_y1_output_root_mean_squared_error: 3.0982 - val_y2_output_root_mean_squared_error: 3.3340
# Epoch 9/500
# 614/614 [==============================] - 0s 127us/sample - loss: 21.8130 - y1_output_loss: 8.1161 - y2_output_loss: 13.5460 - y1_output_root_mean_squared_error: 2.8585 - y2_output_root_mean_squared_error: 3.6935 - val_loss: 23.1126 - val_y1_output_loss: 8.8581 - val_y2_output_loss: 13.7869 - val_y1_output_root_mean_squared_error: 3.0137 - val_y2_output_root_mean_squared_error: 3.7457
# Epoch 10/500
# 614/614 [==============================] - 0s 126us/sample - loss: 18.6084 - y1_output_loss: 7.5173 - y2_output_loss: 11.0141 - y1_output_root_mean_squared_error: 2.7537 - y2_output_root_mean_squared_error: 3.3205 - val_loss: 26.7834 - val_y1_output_loss: 9.9368 - val_y2_output_loss: 16.6650 - val_y1_output_root_mean_squared_error: 3.1745 - val_y2_output_root_mean_squared_error: 4.0873
# Epoch 11/500
# 614/614 [==============================] - 0s 128us/sample - loss: 20.5873 - y1_output_loss: 7.7965 - y2_output_loss: 12.8991 - y1_output_root_mean_squared_error: 2.7862 - y2_output_root_mean_squared_error: 3.5811 - val_loss: 29.3586 - val_y1_output_loss: 11.1310 - val_y2_output_loss: 17.6439 - val_y1_output_root_mean_squared_error: 3.3823 - val_y2_output_root_mean_squared_error: 4.2330
# Epoch 12/500
# 614/614 [==============================] - 0s 126us/sample - loss: 18.6407 - y1_output_loss: 7.4448 - y2_output_loss: 11.4637 - y1_output_root_mean_squared_error: 2.7060 - y2_output_root_mean_squared_error: 3.3643 - val_loss: 16.4001 - val_y1_output_loss: 7.8040 - val_y2_output_loss: 8.1938 - val_y1_output_root_mean_squared_error: 2.8194 - val_y2_output_root_mean_squared_error: 2.9071
# Epoch 13/500
# 614/614 [==============================] - 0s 127us/sample - loss: 20.6694 - y1_output_loss: 7.7249 - y2_output_loss: 13.3143 - y1_output_root_mean_squared_error: 2.7601 - y2_output_root_mean_squared_error: 3.6126 - val_loss: 24.4929 - val_y1_output_loss: 11.1451 - val_y2_output_loss: 12.8293 - val_y1_output_root_mean_squared_error: 3.3674 - val_y2_output_root_mean_squared_error: 3.6267
# Epoch 14/500
# 614/614 [==============================] - 0s 125us/sample - loss: 17.0444 - y1_output_loss: 6.9180 - y2_output_loss: 10.0894 - y1_output_root_mean_squared_error: 2.6297 - y2_output_root_mean_squared_error: 3.1826 - val_loss: 24.3277 - val_y1_output_loss: 8.2069 - val_y2_output_loss: 15.7942 - val_y1_output_root_mean_squared_error: 2.9017 - val_y2_output_root_mean_squared_error: 3.9885
# Epoch 15/500
# 614/614 [==============================] - 0s 125us/sample - loss: 18.5849 - y1_output_loss: 7.0405 - y2_output_loss: 11.4825 - y1_output_root_mean_squared_error: 2.6593 - y2_output_root_mean_squared_error: 3.3931 - val_loss: 15.1430 - val_y1_output_loss: 6.3778 - val_y2_output_loss: 8.3467 - val_y1_output_root_mean_squared_error: 2.5608 - val_y2_output_root_mean_squared_error: 2.9301
# Epoch 16/500
# 614/614 [==============================] - 0s 124us/sample - loss: 18.7469 - y1_output_loss: 6.6157 - y2_output_loss: 11.9908 - y1_output_root_mean_squared_error: 2.5811 - y2_output_root_mean_squared_error: 3.4763 - val_loss: 16.8843 - val_y1_output_loss: 7.1764 - val_y2_output_loss: 9.2285 - val_y1_output_root_mean_squared_error: 2.7237 - val_y2_output_root_mean_squared_error: 3.0767
# Epoch 17/500
# 614/614 [==============================] - 0s 124us/sample - loss: 17.1221 - y1_output_loss: 6.3410 - y2_output_loss: 10.7322 - y1_output_root_mean_squared_error: 2.5270 - y2_output_root_mean_squared_error: 3.2767 - val_loss: 19.1306 - val_y1_output_loss: 6.9564 - val_y2_output_loss: 11.7813 - val_y1_output_root_mean_squared_error: 2.6749 - val_y2_output_root_mean_squared_error: 3.4605
# Epoch 18/500
# 614/614 [==============================] - 0s 127us/sample - loss: 16.2213 - y1_output_loss: 5.9299 - y2_output_loss: 10.2421 - y1_output_root_mean_squared_error: 2.4448 - y2_output_root_mean_squared_error: 3.2007 - val_loss: 54.8307 - val_y1_output_loss: 12.3992 - val_y2_output_loss: 42.8963 - val_y1_output_root_mean_squared_error: 3.5378 - val_y2_output_root_mean_squared_error: 6.5049
# Epoch 19/500
# 614/614 [==============================] - 0s 141us/sample - loss: 20.9946 - y1_output_loss: 6.9767 - y2_output_loss: 14.0949 - y1_output_root_mean_squared_error: 2.6438 - y2_output_root_mean_squared_error: 3.7423 - val_loss: 32.7045 - val_y1_output_loss: 9.2854 - val_y2_output_loss: 23.0154 - val_y1_output_root_mean_squared_error: 3.0967 - val_y2_output_root_mean_squared_error: 4.8078
# Epoch 20/500
# 614/614 [==============================] - 0s 132us/sample - loss: 19.5049 - y1_output_loss: 6.6620 - y2_output_loss: 12.9237 - y1_output_root_mean_squared_error: 2.5777 - y2_output_root_mean_squared_error: 3.5862 - val_loss: 15.3663 - val_y1_output_loss: 6.1955 - val_y2_output_loss: 8.8051 - val_y1_output_root_mean_squared_error: 2.5241 - val_y2_output_root_mean_squared_error: 2.9992
# Epoch 21/500
# 614/614 [==============================] - 0s 138us/sample - loss: 16.0926 - y1_output_loss: 5.9582 - y2_output_loss: 10.0560 - y1_output_root_mean_squared_error: 2.4469 - y2_output_root_mean_squared_error: 3.1788 - val_loss: 14.8511 - val_y1_output_loss: 6.4443 - val_y2_output_loss: 7.9953 - val_y1_output_root_mean_squared_error: 2.5787 - val_y2_output_root_mean_squared_error: 2.8638
# Epoch 22/500
# 614/614 [==============================] - 0s 135us/sample - loss: 16.2525 - y1_output_loss: 5.7553 - y2_output_loss: 10.4385 - y1_output_root_mean_squared_error: 2.3941 - y2_output_root_mean_squared_error: 3.2436 - val_loss: 13.5824 - val_y1_output_loss: 6.1577 - val_y2_output_loss: 7.0677 - val_y1_output_root_mean_squared_error: 2.5260 - val_y2_output_root_mean_squared_error: 2.6836
# Epoch 23/500
# 614/614 [==============================] - 0s 138us/sample - loss: 18.4048 - y1_output_loss: 6.0750 - y2_output_loss: 12.2573 - y1_output_root_mean_squared_error: 2.4738 - y2_output_root_mean_squared_error: 3.5050 - val_loss: 24.7266 - val_y1_output_loss: 9.0685 - val_y2_output_loss: 15.3475 - val_y1_output_root_mean_squared_error: 3.0441 - val_y2_output_root_mean_squared_error: 3.9319
# Epoch 24/500
# 614/614 [==============================] - 0s 134us/sample - loss: 14.3678 - y1_output_loss: 5.1888 - y2_output_loss: 9.0937 - y1_output_root_mean_squared_error: 2.2782 - y2_output_root_mean_squared_error: 3.0295 - val_loss: 11.7929 - val_y1_output_loss: 4.6953 - val_y2_output_loss: 6.8364 - val_y1_output_root_mean_squared_error: 2.1998 - val_y2_output_root_mean_squared_error: 2.6370
# Epoch 25/500
# 614/614 [==============================] - 0s 139us/sample - loss: 13.7608 - y1_output_loss: 5.0355 - y2_output_loss: 8.9706 - y1_output_root_mean_squared_error: 2.2427 - y2_output_root_mean_squared_error: 2.9548 - val_loss: 32.1824 - val_y1_output_loss: 7.6632 - val_y2_output_loss: 24.8535 - val_y1_output_root_mean_squared_error: 2.7786 - val_y2_output_root_mean_squared_error: 4.9459
# Epoch 26/500
# 614/614 [==============================] - 0s 138us/sample - loss: 13.5047 - y1_output_loss: 4.7831 - y2_output_loss: 8.6489 - y1_output_root_mean_squared_error: 2.1908 - y2_output_root_mean_squared_error: 2.9504 - val_loss: 11.8507 - val_y1_output_loss: 4.9465 - val_y2_output_loss: 6.6236 - val_y1_output_root_mean_squared_error: 2.2602 - val_y2_output_root_mean_squared_error: 2.5966
# Epoch 27/500
# 614/614 [==============================] - 0s 135us/sample - loss: 12.8233 - y1_output_loss: 4.7174 - y2_output_loss: 8.0932 - y1_output_root_mean_squared_error: 2.1759 - y2_output_root_mean_squared_error: 2.8441 - val_loss: 12.7419 - val_y1_output_loss: 5.4579 - val_y2_output_loss: 7.1265 - val_y1_output_root_mean_squared_error: 2.3534 - val_y2_output_root_mean_squared_error: 2.6840
# Epoch 28/500
# 614/614 [==============================] - 0s 138us/sample - loss: 10.9924 - y1_output_loss: 4.2952 - y2_output_loss: 6.6245 - y1_output_root_mean_squared_error: 2.0782 - y2_output_root_mean_squared_error: 2.5833 - val_loss: 11.7079 - val_y1_output_loss: 4.4477 - val_y2_output_loss: 7.0158 - val_y1_output_root_mean_squared_error: 2.1425 - val_y2_output_root_mean_squared_error: 2.6679
# Epoch 29/500
# 614/614 [==============================] - 0s 128us/sample - loss: 12.0258 - y1_output_loss: 4.4068 - y2_output_loss: 7.6794 - y1_output_root_mean_squared_error: 2.0906 - y2_output_root_mean_squared_error: 2.7668 - val_loss: 15.7013 - val_y1_output_loss: 6.3102 - val_y2_output_loss: 9.7825 - val_y1_output_root_mean_squared_error: 2.4902 - val_y2_output_root_mean_squared_error: 3.0822
# Epoch 30/500
# 614/614 [==============================] - 0s 127us/sample - loss: 14.6273 - y1_output_loss: 4.6325 - y2_output_loss: 9.9014 - y1_output_root_mean_squared_error: 2.1572 - y2_output_root_mean_squared_error: 3.1581 - val_loss: 10.4055 - val_y1_output_loss: 4.0729 - val_y2_output_loss: 6.1104 - val_y1_output_root_mean_squared_error: 2.0502 - val_y2_output_root_mean_squared_error: 2.4904
# Epoch 31/500
# 614/614 [==============================] - 0s 126us/sample - loss: 12.7766 - y1_output_loss: 4.2908 - y2_output_loss: 8.6105 - y1_output_root_mean_squared_error: 2.0629 - y2_output_root_mean_squared_error: 2.9191 - val_loss: 11.2807 - val_y1_output_loss: 3.9794 - val_y2_output_loss: 7.0416 - val_y1_output_root_mean_squared_error: 2.0312 - val_y2_output_root_mean_squared_error: 2.6749
# Epoch 32/500
# 614/614 [==============================] - 0s 134us/sample - loss: 12.8227 - y1_output_loss: 4.2620 - y2_output_loss: 8.4789 - y1_output_root_mean_squared_error: 2.0718 - y2_output_root_mean_squared_error: 2.9206 - val_loss: 11.7365 - val_y1_output_loss: 4.1993 - val_y2_output_loss: 7.2231 - val_y1_output_root_mean_squared_error: 2.0805 - val_y2_output_root_mean_squared_error: 2.7218
# Epoch 33/500
# 614/614 [==============================] - 0s 124us/sample - loss: 12.3161 - y1_output_loss: 4.0878 - y2_output_loss: 8.1675 - y1_output_root_mean_squared_error: 2.0192 - y2_output_root_mean_squared_error: 2.8704 - val_loss: 9.9423 - val_y1_output_loss: 3.4868 - val_y2_output_loss: 6.4101 - val_y1_output_root_mean_squared_error: 1.8907 - val_y2_output_root_mean_squared_error: 2.5234
# Epoch 34/500
# 614/614 [==============================] - 0s 125us/sample - loss: 11.5833 - y1_output_loss: 3.7908 - y2_output_loss: 7.9611 - y1_output_root_mean_squared_error: 1.9482 - y2_output_root_mean_squared_error: 2.7906 - val_loss: 24.6309 - val_y1_output_loss: 6.6202 - val_y2_output_loss: 18.5311 - val_y1_output_root_mean_squared_error: 2.5560 - val_y2_output_root_mean_squared_error: 4.2542
# Epoch 35/500
# 614/614 [==============================] - 0s 125us/sample - loss: 10.1478 - y1_output_loss: 3.6437 - y2_output_loss: 6.4622 - y1_output_root_mean_squared_error: 1.9117 - y2_output_root_mean_squared_error: 2.5482 - val_loss: 9.9638 - val_y1_output_loss: 3.5178 - val_y2_output_loss: 6.3372 - val_y1_output_root_mean_squared_error: 1.8888 - val_y2_output_root_mean_squared_error: 2.5290
# Epoch 36/500
# 614/614 [==============================] - 0s 124us/sample - loss: 11.0550 - y1_output_loss: 3.5540 - y2_output_loss: 7.4731 - y1_output_root_mean_squared_error: 1.8843 - y2_output_root_mean_squared_error: 2.7394 - val_loss: 16.7584 - val_y1_output_loss: 5.4971 - val_y2_output_loss: 11.7453 - val_y1_output_root_mean_squared_error: 2.3148 - val_y2_output_root_mean_squared_error: 3.3764
# Epoch 37/500
# 614/614 [==============================] - 0s 126us/sample - loss: 9.1881 - y1_output_loss: 3.1233 - y2_output_loss: 6.0310 - y1_output_root_mean_squared_error: 1.7699 - y2_output_root_mean_squared_error: 2.4608 - val_loss: 10.7322 - val_y1_output_loss: 2.7565 - val_y2_output_loss: 7.7464 - val_y1_output_root_mean_squared_error: 1.6904 - val_y2_output_root_mean_squared_error: 2.8062
# Epoch 38/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.0671 - y1_output_loss: 3.1370 - y2_output_loss: 6.0985 - y1_output_root_mean_squared_error: 1.7592 - y2_output_root_mean_squared_error: 2.4439 - val_loss: 20.8442 - val_y1_output_loss: 7.0153 - val_y2_output_loss: 14.5147 - val_y1_output_root_mean_squared_error: 2.6038 - val_y2_output_root_mean_squared_error: 3.7503
# Epoch 39/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.6531 - y1_output_loss: 2.9456 - y2_output_loss: 5.7015 - y1_output_root_mean_squared_error: 1.7236 - y2_output_root_mean_squared_error: 2.3838 - val_loss: 11.7976 - val_y1_output_loss: 3.5010 - val_y2_output_loss: 8.1090 - val_y1_output_root_mean_squared_error: 1.8967 - val_y2_output_root_mean_squared_error: 2.8636
# Epoch 40/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.1841 - y1_output_loss: 2.7267 - y2_output_loss: 5.4391 - y1_output_root_mean_squared_error: 1.6563 - y2_output_root_mean_squared_error: 2.3326 - val_loss: 7.5634 - val_y1_output_loss: 2.6527 - val_y2_output_loss: 4.7903 - val_y1_output_root_mean_squared_error: 1.6539 - val_y2_output_root_mean_squared_error: 2.1973
# Epoch 41/500
# 614/614 [==============================] - 0s 136us/sample - loss: 10.8148 - y1_output_loss: 3.5361 - y2_output_loss: 7.2835 - y1_output_root_mean_squared_error: 1.8782 - y2_output_root_mean_squared_error: 2.6995 - val_loss: 7.6915 - val_y1_output_loss: 2.5976 - val_y2_output_loss: 5.2302 - val_y1_output_root_mean_squared_error: 1.6047 - val_y2_output_root_mean_squared_error: 2.2620
# Epoch 42/500
# 614/614 [==============================] - 0s 125us/sample - loss: 9.5902 - y1_output_loss: 3.1016 - y2_output_loss: 6.4089 - y1_output_root_mean_squared_error: 1.7686 - y2_output_root_mean_squared_error: 2.5421 - val_loss: 7.0096 - val_y1_output_loss: 2.4386 - val_y2_output_loss: 4.5747 - val_y1_output_root_mean_squared_error: 1.5657 - val_y2_output_root_mean_squared_error: 2.1350
# Epoch 43/500
# 614/614 [==============================] - 0s 135us/sample - loss: 9.3150 - y1_output_loss: 3.0014 - y2_output_loss: 6.3780 - y1_output_root_mean_squared_error: 1.7201 - y2_output_root_mean_squared_error: 2.5212 - val_loss: 12.5425 - val_y1_output_loss: 4.3984 - val_y2_output_loss: 8.5835 - val_y1_output_root_mean_squared_error: 2.0592 - val_y2_output_root_mean_squared_error: 2.8813
# Epoch 44/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.1005 - y1_output_loss: 2.9455 - y2_output_loss: 6.1166 - y1_output_root_mean_squared_error: 1.7220 - y2_output_root_mean_squared_error: 2.4769 - val_loss: 7.7103 - val_y1_output_loss: 3.1004 - val_y2_output_loss: 4.7290 - val_y1_output_root_mean_squared_error: 1.7472 - val_y2_output_root_mean_squared_error: 2.1582
# Epoch 45/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.1917 - y1_output_loss: 2.5738 - y2_output_loss: 5.7133 - y1_output_root_mean_squared_error: 1.5939 - y2_output_root_mean_squared_error: 2.3772 - val_loss: 22.7435 - val_y1_output_loss: 7.1842 - val_y2_output_loss: 16.5086 - val_y1_output_root_mean_squared_error: 2.6168 - val_y2_output_root_mean_squared_error: 3.9869
# Epoch 46/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.8706 - y1_output_loss: 2.5638 - y2_output_loss: 5.2848 - y1_output_root_mean_squared_error: 1.6075 - y2_output_root_mean_squared_error: 2.2993 - val_loss: 6.9952 - val_y1_output_loss: 2.3137 - val_y2_output_loss: 4.6241 - val_y1_output_root_mean_squared_error: 1.5333 - val_y2_output_root_mean_squared_error: 2.1550
# Epoch 47/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.8352 - y1_output_loss: 2.6112 - y2_output_loss: 5.1624 - y1_output_root_mean_squared_error: 1.6230 - y2_output_root_mean_squared_error: 2.2806 - val_loss: 6.9180 - val_y1_output_loss: 2.2280 - val_y2_output_loss: 4.6425 - val_y1_output_root_mean_squared_error: 1.5028 - val_y2_output_root_mean_squared_error: 2.1586
# Epoch 48/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.7282 - y1_output_loss: 2.6205 - y2_output_loss: 5.1355 - y1_output_root_mean_squared_error: 1.6184 - y2_output_root_mean_squared_error: 2.2603 - val_loss: 17.3978 - val_y1_output_loss: 5.7889 - val_y2_output_loss: 12.3815 - val_y1_output_root_mean_squared_error: 2.3435 - val_y2_output_root_mean_squared_error: 3.4505
# Epoch 49/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.5111 - y1_output_loss: 2.4484 - y2_output_loss: 5.0566 - y1_output_root_mean_squared_error: 1.5574 - y2_output_root_mean_squared_error: 2.2551 - val_loss: 8.9532 - val_y1_output_loss: 2.6566 - val_y2_output_loss: 6.1211 - val_y1_output_root_mean_squared_error: 1.6570 - val_y2_output_root_mean_squared_error: 2.4915
# Epoch 50/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.7629 - y1_output_loss: 2.4434 - y2_output_loss: 5.2751 - y1_output_root_mean_squared_error: 1.5682 - y2_output_root_mean_squared_error: 2.3030 - val_loss: 6.9435 - val_y1_output_loss: 2.2079 - val_y2_output_loss: 4.9378 - val_y1_output_root_mean_squared_error: 1.4614 - val_y2_output_root_mean_squared_error: 2.1927
# Epoch 51/500
# 614/614 [==============================] - 0s 126us/sample - loss: 8.1844 - y1_output_loss: 2.3796 - y2_output_loss: 5.7996 - y1_output_root_mean_squared_error: 1.5455 - y2_output_root_mean_squared_error: 2.4075 - val_loss: 7.9952 - val_y1_output_loss: 2.1894 - val_y2_output_loss: 5.6566 - val_y1_output_root_mean_squared_error: 1.5038 - val_y2_output_root_mean_squared_error: 2.3945
# Epoch 52/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.4256 - y1_output_loss: 2.1097 - y2_output_loss: 4.2954 - y1_output_root_mean_squared_error: 1.4543 - y2_output_root_mean_squared_error: 2.0762 - val_loss: 9.6414 - val_y1_output_loss: 2.7089 - val_y2_output_loss: 6.7177 - val_y1_output_root_mean_squared_error: 1.6744 - val_y2_output_root_mean_squared_error: 2.6149
# Epoch 53/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.8741 - y1_output_loss: 2.3546 - y2_output_loss: 5.4863 - y1_output_root_mean_squared_error: 1.5398 - y2_output_root_mean_squared_error: 2.3459 - val_loss: 9.6037 - val_y1_output_loss: 2.7007 - val_y2_output_loss: 7.1323 - val_y1_output_root_mean_squared_error: 1.6309 - val_y2_output_root_mean_squared_error: 2.6351
# Epoch 54/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.1458 - y1_output_loss: 1.9446 - y2_output_loss: 4.2450 - y1_output_root_mean_squared_error: 1.3907 - y2_output_root_mean_squared_error: 2.0523 - val_loss: 16.2599 - val_y1_output_loss: 2.7337 - val_y2_output_loss: 13.4302 - val_y1_output_root_mean_squared_error: 1.6697 - val_y2_output_root_mean_squared_error: 3.6704
# Epoch 55/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.3441 - y1_output_loss: 2.2619 - y2_output_loss: 5.0838 - y1_output_root_mean_squared_error: 1.5052 - y2_output_root_mean_squared_error: 2.2536 - val_loss: 6.7147 - val_y1_output_loss: 2.3820 - val_y2_output_loss: 4.2803 - val_y1_output_root_mean_squared_error: 1.5361 - val_y2_output_root_mean_squared_error: 2.0869
# Epoch 56/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.8620 - y1_output_loss: 2.0445 - y2_output_loss: 4.7537 - y1_output_root_mean_squared_error: 1.4366 - y2_output_root_mean_squared_error: 2.1905 - val_loss: 5.7521 - val_y1_output_loss: 1.7903 - val_y2_output_loss: 3.9213 - val_y1_output_root_mean_squared_error: 1.3494 - val_y2_output_root_mean_squared_error: 1.9827
# Epoch 57/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.9597 - y1_output_loss: 1.7680 - y2_output_loss: 4.2025 - y1_output_root_mean_squared_error: 1.3274 - y2_output_root_mean_squared_error: 2.0488 - val_loss: 16.5594 - val_y1_output_loss: 4.7863 - val_y2_output_loss: 12.2817 - val_y1_output_root_mean_squared_error: 2.1524 - val_y2_output_root_mean_squared_error: 3.4535
# Epoch 58/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.8168 - y1_output_loss: 2.3029 - y2_output_loss: 5.5233 - y1_output_root_mean_squared_error: 1.5168 - y2_output_root_mean_squared_error: 2.3486 - val_loss: 18.2946 - val_y1_output_loss: 4.5185 - val_y2_output_loss: 13.8553 - val_y1_output_root_mean_squared_error: 2.1284 - val_y2_output_root_mean_squared_error: 3.7101
# Epoch 59/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.1700 - y1_output_loss: 1.9608 - y2_output_loss: 5.1691 - y1_output_root_mean_squared_error: 1.4058 - y2_output_root_mean_squared_error: 2.2790 - val_loss: 9.3077 - val_y1_output_loss: 2.9980 - val_y2_output_loss: 6.4765 - val_y1_output_root_mean_squared_error: 1.7196 - val_y2_output_root_mean_squared_error: 2.5201
# Epoch 60/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.1344 - y1_output_loss: 2.0040 - y2_output_loss: 5.1441 - y1_output_root_mean_squared_error: 1.4163 - y2_output_root_mean_squared_error: 2.2646 - val_loss: 5.2897 - val_y1_output_loss: 1.5127 - val_y2_output_loss: 3.7104 - val_y1_output_root_mean_squared_error: 1.2409 - val_y2_output_root_mean_squared_error: 1.9365
# Epoch 61/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.2909 - y1_output_loss: 2.8523 - y2_output_loss: 5.4037 - y1_output_root_mean_squared_error: 1.6862 - y2_output_root_mean_squared_error: 2.3340 - val_loss: 5.1614 - val_y1_output_loss: 1.6115 - val_y2_output_loss: 3.5112 - val_y1_output_root_mean_squared_error: 1.2759 - val_y2_output_root_mean_squared_error: 1.8798
# Epoch 62/500
# 614/614 [==============================] - 0s 126us/sample - loss: 9.3271 - y1_output_loss: 2.5944 - y2_output_loss: 6.6598 - y1_output_root_mean_squared_error: 1.6132 - y2_output_root_mean_squared_error: 2.5932 - val_loss: 4.6607 - val_y1_output_loss: 1.2188 - val_y2_output_loss: 3.4369 - val_y1_output_root_mean_squared_error: 1.1149 - val_y2_output_root_mean_squared_error: 1.8487
# Epoch 63/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.1816 - y1_output_loss: 1.6127 - y2_output_loss: 3.5464 - y1_output_root_mean_squared_error: 1.2670 - y2_output_root_mean_squared_error: 1.8911 - val_loss: 4.8436 - val_y1_output_loss: 1.5858 - val_y2_output_loss: 3.2730 - val_y1_output_root_mean_squared_error: 1.2533 - val_y2_output_root_mean_squared_error: 1.8091
# Epoch 64/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.7136 - y1_output_loss: 1.6739 - y2_output_loss: 4.0129 - y1_output_root_mean_squared_error: 1.2967 - y2_output_root_mean_squared_error: 2.0080 - val_loss: 5.9894 - val_y1_output_loss: 1.2225 - val_y2_output_loss: 4.8234 - val_y1_output_root_mean_squared_error: 1.1198 - val_y2_output_root_mean_squared_error: 2.1761
# Epoch 65/500
# 614/614 [==============================] - 0s 124us/sample - loss: 5.7513 - y1_output_loss: 1.4615 - y2_output_loss: 4.2403 - y1_output_root_mean_squared_error: 1.2128 - y2_output_root_mean_squared_error: 2.0689 - val_loss: 11.9817 - val_y1_output_loss: 3.6301 - val_y2_output_loss: 8.6717 - val_y1_output_root_mean_squared_error: 1.8764 - val_y2_output_root_mean_squared_error: 2.9088
# Epoch 66/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.9806 - y1_output_loss: 1.6040 - y2_output_loss: 4.3779 - y1_output_root_mean_squared_error: 1.2647 - y2_output_root_mean_squared_error: 2.0931 - val_loss: 7.4829 - val_y1_output_loss: 2.0910 - val_y2_output_loss: 5.4175 - val_y1_output_root_mean_squared_error: 1.4453 - val_y2_output_root_mean_squared_error: 2.3225
# Epoch 67/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.0286 - y1_output_loss: 2.2010 - y2_output_loss: 4.9546 - y1_output_root_mean_squared_error: 1.4708 - y2_output_root_mean_squared_error: 2.2058 - val_loss: 25.7037 - val_y1_output_loss: 7.6469 - val_y2_output_loss: 18.9851 - val_y1_output_root_mean_squared_error: 2.7045 - val_y2_output_root_mean_squared_error: 4.2883
# Epoch 68/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.9145 - y1_output_loss: 1.3284 - y2_output_loss: 3.5990 - y1_output_root_mean_squared_error: 1.1434 - y2_output_root_mean_squared_error: 1.8993 - val_loss: 6.5670 - val_y1_output_loss: 1.9596 - val_y2_output_loss: 4.6852 - val_y1_output_root_mean_squared_error: 1.3899 - val_y2_output_root_mean_squared_error: 2.1529
# Epoch 69/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.9177 - y1_output_loss: 1.1020 - y2_output_loss: 2.8978 - y1_output_root_mean_squared_error: 1.0328 - y2_output_root_mean_squared_error: 1.6885 - val_loss: 33.1323 - val_y1_output_loss: 8.4484 - val_y2_output_loss: 25.4470 - val_y1_output_root_mean_squared_error: 2.8803 - val_y2_output_root_mean_squared_error: 4.9836
# Epoch 70/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.5521 - y1_output_loss: 1.8585 - y2_output_loss: 4.6456 - y1_output_root_mean_squared_error: 1.3670 - y2_output_root_mean_squared_error: 2.1641 - val_loss: 4.8794 - val_y1_output_loss: 1.2434 - val_y2_output_loss: 3.6166 - val_y1_output_root_mean_squared_error: 1.1274 - val_y2_output_root_mean_squared_error: 1.8996
# Epoch 71/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.6957 - y1_output_loss: 1.5109 - y2_output_loss: 4.2309 - y1_output_root_mean_squared_error: 1.2326 - y2_output_root_mean_squared_error: 2.0436 - val_loss: 7.5049 - val_y1_output_loss: 1.6141 - val_y2_output_loss: 5.8535 - val_y1_output_root_mean_squared_error: 1.2879 - val_y2_output_root_mean_squared_error: 2.4179
# Epoch 72/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.6507 - y1_output_loss: 1.6827 - y2_output_loss: 3.9269 - y1_output_root_mean_squared_error: 1.3006 - y2_output_root_mean_squared_error: 1.9897 - val_loss: 4.2961 - val_y1_output_loss: 1.1515 - val_y2_output_loss: 3.1231 - val_y1_output_root_mean_squared_error: 1.0877 - val_y2_output_root_mean_squared_error: 1.7644
# Epoch 73/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.4484 - y1_output_loss: 1.2015 - y2_output_loss: 3.2315 - y1_output_root_mean_squared_error: 1.0952 - y2_output_root_mean_squared_error: 1.8025 - val_loss: 4.1051 - val_y1_output_loss: 1.1051 - val_y2_output_loss: 2.9456 - val_y1_output_root_mean_squared_error: 1.0661 - val_y2_output_root_mean_squared_error: 1.7230
# Epoch 74/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.5514 - y1_output_loss: 0.9800 - y2_output_loss: 2.5685 - y1_output_root_mean_squared_error: 0.9926 - y2_output_root_mean_squared_error: 1.6019 - val_loss: 9.7205 - val_y1_output_loss: 2.7054 - val_y2_output_loss: 6.9744 - val_y1_output_root_mean_squared_error: 1.6620 - val_y2_output_root_mean_squared_error: 2.6378
# Epoch 75/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.9800 - y1_output_loss: 1.1082 - y2_output_loss: 2.8401 - y1_output_root_mean_squared_error: 1.0562 - y2_output_root_mean_squared_error: 1.6925 - val_loss: 3.9222 - val_y1_output_loss: 0.7120 - val_y2_output_loss: 3.2419 - val_y1_output_root_mean_squared_error: 0.8526 - val_y2_output_root_mean_squared_error: 1.7875
# Epoch 76/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.7183 - y1_output_loss: 0.8735 - y2_output_loss: 2.8972 - y1_output_root_mean_squared_error: 0.9375 - y2_output_root_mean_squared_error: 1.6850 - val_loss: 4.3564 - val_y1_output_loss: 1.2209 - val_y2_output_loss: 3.0511 - val_y1_output_root_mean_squared_error: 1.1245 - val_y2_output_root_mean_squared_error: 1.7584
# Epoch 77/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.9129 - y1_output_loss: 0.9199 - y2_output_loss: 2.9908 - y1_output_root_mean_squared_error: 0.9624 - y2_output_root_mean_squared_error: 1.7282 - val_loss: 4.8385 - val_y1_output_loss: 1.4045 - val_y2_output_loss: 3.3492 - val_y1_output_root_mean_squared_error: 1.2068 - val_y2_output_root_mean_squared_error: 1.8391
# Epoch 78/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.0889 - y1_output_loss: 1.1150 - y2_output_loss: 2.9777 - y1_output_root_mean_squared_error: 1.0555 - y2_output_root_mean_squared_error: 1.7247 - val_loss: 6.1104 - val_y1_output_loss: 1.5852 - val_y2_output_loss: 4.6653 - val_y1_output_root_mean_squared_error: 1.2380 - val_y2_output_root_mean_squared_error: 2.1396
# Epoch 79/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.7045 - y1_output_loss: 0.9263 - y2_output_loss: 2.7575 - y1_output_root_mean_squared_error: 0.9630 - y2_output_root_mean_squared_error: 1.6665 - val_loss: 3.8389 - val_y1_output_loss: 0.6992 - val_y2_output_loss: 3.0915 - val_y1_output_root_mean_squared_error: 0.8523 - val_y2_output_root_mean_squared_error: 1.7642
# Epoch 80/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.6849 - y1_output_loss: 0.9247 - y2_output_loss: 2.8151 - y1_output_root_mean_squared_error: 0.9581 - y2_output_root_mean_squared_error: 1.6634 - val_loss: 9.9441 - val_y1_output_loss: 1.4883 - val_y2_output_loss: 8.5562 - val_y1_output_root_mean_squared_error: 1.2178 - val_y2_output_root_mean_squared_error: 2.9088
# Epoch 81/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.6983 - y1_output_loss: 1.1319 - y2_output_loss: 3.5295 - y1_output_root_mean_squared_error: 1.0672 - y2_output_root_mean_squared_error: 1.8866 - val_loss: 3.8919 - val_y1_output_loss: 0.8530 - val_y2_output_loss: 3.0378 - val_y1_output_root_mean_squared_error: 0.9294 - val_y2_output_root_mean_squared_error: 1.7402
# Epoch 82/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.0967 - y1_output_loss: 1.3669 - y2_output_loss: 3.6973 - y1_output_root_mean_squared_error: 1.1734 - y2_output_root_mean_squared_error: 1.9287 - val_loss: 5.0992 - val_y1_output_loss: 1.1580 - val_y2_output_loss: 3.9808 - val_y1_output_root_mean_squared_error: 1.0767 - val_y2_output_root_mean_squared_error: 1.9849
# Epoch 83/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.1227 - y1_output_loss: 1.1901 - y2_output_loss: 3.9042 - y1_output_root_mean_squared_error: 1.0946 - y2_output_root_mean_squared_error: 1.9810 - val_loss: 4.6911 - val_y1_output_loss: 1.5790 - val_y2_output_loss: 3.0875 - val_y1_output_root_mean_squared_error: 1.2518 - val_y2_output_root_mean_squared_error: 1.7675
# Epoch 84/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.3657 - y1_output_loss: 0.9062 - y2_output_loss: 2.5071 - y1_output_root_mean_squared_error: 0.9510 - y2_output_root_mean_squared_error: 1.5689 - val_loss: 6.6642 - val_y1_output_loss: 1.1306 - val_y2_output_loss: 5.5105 - val_y1_output_root_mean_squared_error: 1.0731 - val_y2_output_root_mean_squared_error: 2.3479
# Epoch 85/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.6116 - y1_output_loss: 1.4772 - y2_output_loss: 4.1087 - y1_output_root_mean_squared_error: 1.2206 - y2_output_root_mean_squared_error: 2.0302 - val_loss: 5.4065 - val_y1_output_loss: 0.9289 - val_y2_output_loss: 4.5062 - val_y1_output_root_mean_squared_error: 0.9783 - val_y2_output_root_mean_squared_error: 2.1094
# Epoch 86/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.7322 - y1_output_loss: 0.7055 - y2_output_loss: 2.0159 - y1_output_root_mean_squared_error: 0.8415 - y2_output_root_mean_squared_error: 1.4227 - val_loss: 3.6405 - val_y1_output_loss: 0.8965 - val_y2_output_loss: 2.6916 - val_y1_output_root_mean_squared_error: 0.9595 - val_y2_output_root_mean_squared_error: 1.6492
# Epoch 87/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.4699 - y1_output_loss: 0.7766 - y2_output_loss: 2.6651 - y1_output_root_mean_squared_error: 0.8847 - y2_output_root_mean_squared_error: 1.6393 - val_loss: 3.3697 - val_y1_output_loss: 0.6695 - val_y2_output_loss: 2.6671 - val_y1_output_root_mean_squared_error: 0.8325 - val_y2_output_root_mean_squared_error: 1.6360
# Epoch 88/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.9707 - y1_output_loss: 1.0979 - y2_output_loss: 3.8377 - y1_output_root_mean_squared_error: 1.0517 - y2_output_root_mean_squared_error: 1.9658 - val_loss: 3.6665 - val_y1_output_loss: 0.8194 - val_y2_output_loss: 2.8084 - val_y1_output_root_mean_squared_error: 0.9198 - val_y2_output_root_mean_squared_error: 1.6794
# Epoch 89/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.3614 - y1_output_loss: 0.8209 - y2_output_loss: 2.5272 - y1_output_root_mean_squared_error: 0.9046 - y2_output_root_mean_squared_error: 1.5947 - val_loss: 3.1597 - val_y1_output_loss: 0.6368 - val_y2_output_loss: 2.4767 - val_y1_output_root_mean_squared_error: 0.8122 - val_y2_output_root_mean_squared_error: 1.5812
# Epoch 90/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.0815 - y1_output_loss: 1.4296 - y2_output_loss: 3.6174 - y1_output_root_mean_squared_error: 1.1966 - y2_output_root_mean_squared_error: 1.9104 - val_loss: 2.9970 - val_y1_output_loss: 0.5572 - val_y2_output_loss: 2.3918 - val_y1_output_root_mean_squared_error: 0.7594 - val_y2_output_root_mean_squared_error: 1.5557
# Epoch 91/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.9455 - y1_output_loss: 0.8473 - y2_output_loss: 3.1145 - y1_output_root_mean_squared_error: 0.9046 - y2_output_root_mean_squared_error: 1.7684 - val_loss: 8.3686 - val_y1_output_loss: 3.3444 - val_y2_output_loss: 5.4213 - val_y1_output_root_mean_squared_error: 1.7771 - val_y2_output_root_mean_squared_error: 2.2827
# Epoch 92/500
# 614/614 [==============================] - 0s 125us/sample - loss: 8.2476 - y1_output_loss: 2.6906 - y2_output_loss: 5.4879 - y1_output_root_mean_squared_error: 1.6482 - y2_output_root_mean_squared_error: 2.3518 - val_loss: 3.1715 - val_y1_output_loss: 0.8395 - val_y2_output_loss: 2.3501 - val_y1_output_root_mean_squared_error: 0.9070 - val_y2_output_root_mean_squared_error: 1.5326
# Epoch 93/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.4696 - y1_output_loss: 0.8433 - y2_output_loss: 2.7408 - y1_output_root_mean_squared_error: 0.8869 - y2_output_root_mean_squared_error: 1.6380 - val_loss: 11.0350 - val_y1_output_loss: 3.2047 - val_y2_output_loss: 7.9981 - val_y1_output_root_mean_squared_error: 1.7747 - val_y2_output_root_mean_squared_error: 2.8081
# Epoch 94/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.4155 - y1_output_loss: 0.8905 - y2_output_loss: 2.5711 - y1_output_root_mean_squared_error: 0.9412 - y2_output_root_mean_squared_error: 1.5905 - val_loss: 7.1778 - val_y1_output_loss: 0.9306 - val_y2_output_loss: 6.3208 - val_y1_output_root_mean_squared_error: 0.9593 - val_y2_output_root_mean_squared_error: 2.5015
# Epoch 95/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.3065 - y1_output_loss: 0.7886 - y2_output_loss: 2.5127 - y1_output_root_mean_squared_error: 0.8916 - y2_output_root_mean_squared_error: 1.5848 - val_loss: 6.8177 - val_y1_output_loss: 0.6992 - val_y2_output_loss: 6.2012 - val_y1_output_root_mean_squared_error: 0.8458 - val_y2_output_root_mean_squared_error: 2.4703
# Epoch 96/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.0138 - y1_output_loss: 1.9711 - y2_output_loss: 4.0253 - y1_output_root_mean_squared_error: 1.4059 - y2_output_root_mean_squared_error: 2.0093 - val_loss: 3.4445 - val_y1_output_loss: 0.6321 - val_y2_output_loss: 2.7718 - val_y1_output_root_mean_squared_error: 0.8095 - val_y2_output_root_mean_squared_error: 1.6701
# Epoch 97/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.9507 - y1_output_loss: 1.0624 - y2_output_loss: 2.8664 - y1_output_root_mean_squared_error: 1.0324 - y2_output_root_mean_squared_error: 1.6985 - val_loss: 2.8527 - val_y1_output_loss: 0.5586 - val_y2_output_loss: 2.2606 - val_y1_output_root_mean_squared_error: 0.7615 - val_y2_output_root_mean_squared_error: 1.5076
# Epoch 98/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.4463 - y1_output_loss: 0.5358 - y2_output_loss: 1.9149 - y1_output_root_mean_squared_error: 0.7305 - y2_output_root_mean_squared_error: 1.3830 - val_loss: 3.7415 - val_y1_output_loss: 0.9042 - val_y2_output_loss: 2.8422 - val_y1_output_root_mean_squared_error: 0.9584 - val_y2_output_root_mean_squared_error: 1.6801
# Epoch 99/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.5596 - y1_output_loss: 0.5836 - y2_output_loss: 2.0024 - y1_output_root_mean_squared_error: 0.7661 - y2_output_root_mean_squared_error: 1.4045 - val_loss: 3.0270 - val_y1_output_loss: 0.6641 - val_y2_output_loss: 2.3627 - val_y1_output_root_mean_squared_error: 0.8171 - val_y2_output_root_mean_squared_error: 1.5360
# Epoch 100/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.6693 - y1_output_loss: 0.6649 - y2_output_loss: 2.0092 - y1_output_root_mean_squared_error: 0.8054 - y2_output_root_mean_squared_error: 1.4215 - val_loss: 4.5645 - val_y1_output_loss: 1.4766 - val_y2_output_loss: 3.0695 - val_y1_output_root_mean_squared_error: 1.2224 - val_y2_output_root_mean_squared_error: 1.7522
# Epoch 101/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.8108 - y1_output_loss: 0.6625 - y2_output_loss: 2.1550 - y1_output_root_mean_squared_error: 0.8090 - y2_output_root_mean_squared_error: 1.4684 - val_loss: 6.8441 - val_y1_output_loss: 2.0359 - val_y2_output_loss: 4.8255 - val_y1_output_root_mean_squared_error: 1.4249 - val_y2_output_root_mean_squared_error: 2.1941
# Epoch 102/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.9652 - y1_output_loss: 0.6591 - y2_output_loss: 2.3392 - y1_output_root_mean_squared_error: 0.8132 - y2_output_root_mean_squared_error: 1.5179 - val_loss: 7.0221 - val_y1_output_loss: 0.8225 - val_y2_output_loss: 6.2234 - val_y1_output_root_mean_squared_error: 0.9119 - val_y2_output_root_mean_squared_error: 2.4881
# Epoch 103/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.6065 - y1_output_loss: 0.6041 - y2_output_loss: 1.9830 - y1_output_root_mean_squared_error: 0.7793 - y2_output_root_mean_squared_error: 1.4140 - val_loss: 2.5405 - val_y1_output_loss: 0.5466 - val_y2_output_loss: 1.9475 - val_y1_output_root_mean_squared_error: 0.7509 - val_y2_output_root_mean_squared_error: 1.4059
# Epoch 104/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.3356 - y1_output_loss: 0.7884 - y2_output_loss: 2.5803 - y1_output_root_mean_squared_error: 0.8800 - y2_output_root_mean_squared_error: 1.6004 - val_loss: 9.5855 - val_y1_output_loss: 3.3056 - val_y2_output_loss: 6.5652 - val_y1_output_root_mean_squared_error: 1.7828 - val_y2_output_root_mean_squared_error: 2.5313
# Epoch 105/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.7016 - y1_output_loss: 0.6515 - y2_output_loss: 2.0377 - y1_output_root_mean_squared_error: 0.8066 - y2_output_root_mean_squared_error: 1.4321 - val_loss: 2.8167 - val_y1_output_loss: 0.6927 - val_y2_output_loss: 2.0765 - val_y1_output_root_mean_squared_error: 0.8449 - val_y2_output_root_mean_squared_error: 1.4501
# Epoch 106/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.8616 - y1_output_loss: 0.7467 - y2_output_loss: 2.0954 - y1_output_root_mean_squared_error: 0.8667 - y2_output_root_mean_squared_error: 1.4527 - val_loss: 2.4211 - val_y1_output_loss: 0.5485 - val_y2_output_loss: 1.8332 - val_y1_output_root_mean_squared_error: 0.7517 - val_y2_output_root_mean_squared_error: 1.3624
# Epoch 107/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.5006 - y1_output_loss: 0.5723 - y2_output_loss: 1.9167 - y1_output_root_mean_squared_error: 0.7569 - y2_output_root_mean_squared_error: 1.3884 - val_loss: 2.5882 - val_y1_output_loss: 0.4715 - val_y2_output_loss: 2.1041 - val_y1_output_root_mean_squared_error: 0.6976 - val_y2_output_root_mean_squared_error: 1.4497
# Epoch 108/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.4914 - y1_output_loss: 0.6109 - y2_output_loss: 1.8603 - y1_output_root_mean_squared_error: 0.7850 - y2_output_root_mean_squared_error: 1.3694 - val_loss: 2.5406 - val_y1_output_loss: 0.5368 - val_y2_output_loss: 1.9911 - val_y1_output_root_mean_squared_error: 0.7434 - val_y2_output_root_mean_squared_error: 1.4099
# Epoch 109/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.4582 - y1_output_loss: 0.4857 - y2_output_loss: 1.9917 - y1_output_root_mean_squared_error: 0.6929 - y2_output_root_mean_squared_error: 1.4065 - val_loss: 5.8269 - val_y1_output_loss: 0.9998 - val_y2_output_loss: 4.8876 - val_y1_output_root_mean_squared_error: 1.0065 - val_y2_output_root_mean_squared_error: 2.1941
# Epoch 110/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.8412 - y1_output_loss: 0.7354 - y2_output_loss: 2.1047 - y1_output_root_mean_squared_error: 0.8567 - y2_output_root_mean_squared_error: 1.4516 - val_loss: 4.6129 - val_y1_output_loss: 0.4699 - val_y2_output_loss: 4.2296 - val_y1_output_root_mean_squared_error: 0.6965 - val_y2_output_root_mean_squared_error: 2.0317
# Epoch 111/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.1867 - y1_output_loss: 0.5312 - y2_output_loss: 1.6387 - y1_output_root_mean_squared_error: 0.7317 - y2_output_root_mean_squared_error: 1.2850 - val_loss: 2.7777 - val_y1_output_loss: 0.6541 - val_y2_output_loss: 2.1481 - val_y1_output_root_mean_squared_error: 0.8031 - val_y2_output_root_mean_squared_error: 1.4604
# Epoch 112/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.8514 - y1_output_loss: 0.7426 - y2_output_loss: 2.1427 - y1_output_root_mean_squared_error: 0.8628 - y2_output_root_mean_squared_error: 1.4515 - val_loss: 8.4464 - val_y1_output_loss: 1.4327 - val_y2_output_loss: 7.0874 - val_y1_output_root_mean_squared_error: 1.2078 - val_y2_output_root_mean_squared_error: 2.6434
# Epoch 113/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.7649 - y1_output_loss: 0.6745 - y2_output_loss: 2.0776 - y1_output_root_mean_squared_error: 0.8204 - y2_output_root_mean_squared_error: 1.4463 - val_loss: 3.3736 - val_y1_output_loss: 0.6100 - val_y2_output_loss: 2.7596 - val_y1_output_root_mean_squared_error: 0.7805 - val_y2_output_root_mean_squared_error: 1.6626
# Epoch 114/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.1632 - y1_output_loss: 0.7047 - y2_output_loss: 2.4330 - y1_output_root_mean_squared_error: 0.8416 - y2_output_root_mean_squared_error: 1.5668 - val_loss: 2.5212 - val_y1_output_loss: 0.5449 - val_y2_output_loss: 1.9604 - val_y1_output_root_mean_squared_error: 0.7467 - val_y2_output_root_mean_squared_error: 1.4013
# Epoch 115/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.2916 - y1_output_loss: 0.5379 - y2_output_loss: 1.7700 - y1_output_root_mean_squared_error: 0.7322 - y2_output_root_mean_squared_error: 1.3250 - val_loss: 3.3352 - val_y1_output_loss: 0.6482 - val_y2_output_loss: 2.7459 - val_y1_output_root_mean_squared_error: 0.8000 - val_y2_output_root_mean_squared_error: 1.6417
# Epoch 116/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.1052 - y1_output_loss: 0.4828 - y2_output_loss: 1.6043 - y1_output_root_mean_squared_error: 0.6979 - y2_output_root_mean_squared_error: 1.2721 - val_loss: 2.1037 - val_y1_output_loss: 0.4394 - val_y2_output_loss: 1.6405 - val_y1_output_root_mean_squared_error: 0.6747 - val_y2_output_root_mean_squared_error: 1.2839
# Epoch 117/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.0276 - y1_output_loss: 0.4683 - y2_output_loss: 1.5661 - y1_output_root_mean_squared_error: 0.6875 - y2_output_root_mean_squared_error: 1.2470 - val_loss: 6.8420 - val_y1_output_loss: 0.6731 - val_y2_output_loss: 6.2417 - val_y1_output_root_mean_squared_error: 0.8332 - val_y2_output_root_mean_squared_error: 2.4795
# Epoch 118/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.2388 - y1_output_loss: 0.5563 - y2_output_loss: 1.6632 - y1_output_root_mean_squared_error: 0.7494 - y2_output_root_mean_squared_error: 1.2951 - val_loss: 2.5212 - val_y1_output_loss: 0.5207 - val_y2_output_loss: 1.9933 - val_y1_output_root_mean_squared_error: 0.7272 - val_y2_output_root_mean_squared_error: 1.4115
# Epoch 119/500
# 614/614 [==============================] - 0s 126us/sample - loss: 1.8708 - y1_output_loss: 0.4495 - y2_output_loss: 1.4399 - y1_output_root_mean_squared_error: 0.6666 - y2_output_root_mean_squared_error: 1.1944 - val_loss: 3.9758 - val_y1_output_loss: 0.6407 - val_y2_output_loss: 3.3136 - val_y1_output_root_mean_squared_error: 0.8086 - val_y2_output_root_mean_squared_error: 1.8226
# Epoch 120/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.7277 - y1_output_loss: 0.6023 - y2_output_loss: 2.1013 - y1_output_root_mean_squared_error: 0.7797 - y2_output_root_mean_squared_error: 1.4559 - val_loss: 2.2894 - val_y1_output_loss: 0.4861 - val_y2_output_loss: 1.7956 - val_y1_output_root_mean_squared_error: 0.7047 - val_y2_output_root_mean_squared_error: 1.3389
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4652 - y1_output_loss: 0.1266 - y2_output_loss: 0.3369 - y1_output_root_mean_squared_error: 0.3547 - y2_output_root_mean_squared_error: 0.5826 - val_loss: 1.3015 - val_y1_output_loss: 0.3772 - val_y2_output_loss: 0.9381 - val_y1_output_root_mean_squared_error: 0.6101 - val_y2_output_root_mean_squared_error: 0.9640
# Epoch 462/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3932 - y1_output_loss: 0.1353 - y2_output_loss: 0.2576 - y1_output_root_mean_squared_error: 0.3690 - y2_output_root_mean_squared_error: 0.5070 - val_loss: 0.9130 - val_y1_output_loss: 0.1591 - val_y2_output_loss: 0.7454 - val_y1_output_root_mean_squared_error: 0.4003 - val_y2_output_root_mean_squared_error: 0.8676
# Epoch 463/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5223 - y1_output_loss: 0.1617 - y2_output_loss: 0.3591 - y1_output_root_mean_squared_error: 0.4033 - y2_output_root_mean_squared_error: 0.5997 - val_loss: 1.0128 - val_y1_output_loss: 0.1890 - val_y2_output_loss: 0.8441 - val_y1_output_root_mean_squared_error: 0.4347 - val_y2_output_root_mean_squared_error: 0.9077
# Epoch 464/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3660 - y1_output_loss: 0.1293 - y2_output_loss: 0.2395 - y1_output_root_mean_squared_error: 0.3555 - y2_output_root_mean_squared_error: 0.4895 - val_loss: 1.3095 - val_y1_output_loss: 0.3581 - val_y2_output_loss: 0.9340 - val_y1_output_root_mean_squared_error: 0.5969 - val_y2_output_root_mean_squared_error: 0.9763
# Epoch 465/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.6021 - y1_output_loss: 0.1726 - y2_output_loss: 0.4246 - y1_output_root_mean_squared_error: 0.4167 - y2_output_root_mean_squared_error: 0.6545 - val_loss: 0.8629 - val_y1_output_loss: 0.1587 - val_y2_output_loss: 0.6873 - val_y1_output_root_mean_squared_error: 0.3968 - val_y2_output_root_mean_squared_error: 0.8399
# Epoch 466/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3418 - y1_output_loss: 0.1298 - y2_output_loss: 0.2099 - y1_output_root_mean_squared_error: 0.3616 - y2_output_root_mean_squared_error: 0.4594 - val_loss: 0.7104 - val_y1_output_loss: 0.1679 - val_y2_output_loss: 0.5371 - val_y1_output_root_mean_squared_error: 0.4123 - val_y2_output_root_mean_squared_error: 0.7352
# Epoch 467/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3551 - y1_output_loss: 0.1341 - y2_output_loss: 0.2220 - y1_output_root_mean_squared_error: 0.3671 - y2_output_root_mean_squared_error: 0.4694 - val_loss: 1.2059 - val_y1_output_loss: 0.4573 - val_y2_output_loss: 0.8288 - val_y1_output_root_mean_squared_error: 0.6582 - val_y2_output_root_mean_squared_error: 0.8790
# Epoch 468/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3746 - y1_output_loss: 0.1237 - y2_output_loss: 0.2483 - y1_output_root_mean_squared_error: 0.3528 - y2_output_root_mean_squared_error: 0.5001 - val_loss: 0.7350 - val_y1_output_loss: 0.1953 - val_y2_output_loss: 0.5496 - val_y1_output_root_mean_squared_error: 0.4411 - val_y2_output_root_mean_squared_error: 0.7351
# Epoch 469/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4248 - y1_output_loss: 0.1232 - y2_output_loss: 0.2983 - y1_output_root_mean_squared_error: 0.3522 - y2_output_root_mean_squared_error: 0.5484 - val_loss: 0.8071 - val_y1_output_loss: 0.2194 - val_y2_output_loss: 0.5959 - val_y1_output_root_mean_squared_error: 0.4650 - val_y2_output_root_mean_squared_error: 0.7687
# Epoch 470/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4080 - y1_output_loss: 0.1245 - y2_output_loss: 0.2804 - y1_output_root_mean_squared_error: 0.3538 - y2_output_root_mean_squared_error: 0.5318 - val_loss: 0.7517 - val_y1_output_loss: 0.1856 - val_y2_output_loss: 0.5703 - val_y1_output_root_mean_squared_error: 0.4280 - val_y2_output_root_mean_squared_error: 0.7541
# Epoch 471/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3364 - y1_output_loss: 0.1148 - y2_output_loss: 0.2216 - y1_output_root_mean_squared_error: 0.3389 - y2_output_root_mean_squared_error: 0.4707 - val_loss: 0.8346 - val_y1_output_loss: 0.2631 - val_y2_output_loss: 0.5900 - val_y1_output_root_mean_squared_error: 0.5068 - val_y2_output_root_mean_squared_error: 0.7601
# Epoch 472/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.0063 - y1_output_loss: 0.5813 - y2_output_loss: 1.4604 - y1_output_root_mean_squared_error: 0.7629 - y2_output_root_mean_squared_error: 1.1934 - val_loss: 4.9848 - val_y1_output_loss: 0.8877 - val_y2_output_loss: 4.2353 - val_y1_output_root_mean_squared_error: 0.9313 - val_y2_output_root_mean_squared_error: 2.0292
# Epoch 473/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5333 - y1_output_loss: 0.1704 - y2_output_loss: 0.3625 - y1_output_root_mean_squared_error: 0.4126 - y2_output_root_mean_squared_error: 0.6026 - val_loss: 0.9104 - val_y1_output_loss: 0.2238 - val_y2_output_loss: 0.6748 - val_y1_output_root_mean_squared_error: 0.4764 - val_y2_output_root_mean_squared_error: 0.8267
# Epoch 474/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4519 - y1_output_loss: 0.1462 - y2_output_loss: 0.3090 - y1_output_root_mean_squared_error: 0.3781 - y2_output_root_mean_squared_error: 0.5558 - val_loss: 1.1875 - val_y1_output_loss: 0.3213 - val_y2_output_loss: 0.8751 - val_y1_output_root_mean_squared_error: 0.5625 - val_y2_output_root_mean_squared_error: 0.9333
# Epoch 475/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4558 - y1_output_loss: 0.1459 - y2_output_loss: 0.3067 - y1_output_root_mean_squared_error: 0.3835 - y2_output_root_mean_squared_error: 0.5556 - val_loss: 0.9843 - val_y1_output_loss: 0.1948 - val_y2_output_loss: 0.7727 - val_y1_output_root_mean_squared_error: 0.4464 - val_y2_output_root_mean_squared_error: 0.8860
# Epoch 476/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4055 - y1_output_loss: 0.1286 - y2_output_loss: 0.2758 - y1_output_root_mean_squared_error: 0.3599 - y2_output_root_mean_squared_error: 0.5254 - val_loss: 1.0127 - val_y1_output_loss: 0.2741 - val_y2_output_loss: 0.7107 - val_y1_output_root_mean_squared_error: 0.5274 - val_y2_output_root_mean_squared_error: 0.8571
# Epoch 477/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3392 - y1_output_loss: 0.1266 - y2_output_loss: 0.2130 - y1_output_root_mean_squared_error: 0.3573 - y2_output_root_mean_squared_error: 0.4599 - val_loss: 0.6652 - val_y1_output_loss: 0.1809 - val_y2_output_loss: 0.4785 - val_y1_output_root_mean_squared_error: 0.4260 - val_y2_output_root_mean_squared_error: 0.6955
# Epoch 478/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3715 - y1_output_loss: 0.1320 - y2_output_loss: 0.2507 - y1_output_root_mean_squared_error: 0.3566 - y2_output_root_mean_squared_error: 0.4943 - val_loss: 1.5913 - val_y1_output_loss: 0.5696 - val_y2_output_loss: 1.0362 - val_y1_output_root_mean_squared_error: 0.7515 - val_y2_output_root_mean_squared_error: 1.0132
# Epoch 479/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4502 - y1_output_loss: 0.1374 - y2_output_loss: 0.3121 - y1_output_root_mean_squared_error: 0.3693 - y2_output_root_mean_squared_error: 0.5602 - val_loss: 0.9083 - val_y1_output_loss: 0.2534 - val_y2_output_loss: 0.6382 - val_y1_output_root_mean_squared_error: 0.5074 - val_y2_output_root_mean_squared_error: 0.8068
# Epoch 480/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3627 - y1_output_loss: 0.1180 - y2_output_loss: 0.2418 - y1_output_root_mean_squared_error: 0.3451 - y2_output_root_mean_squared_error: 0.4936 - val_loss: 0.7916 - val_y1_output_loss: 0.1989 - val_y2_output_loss: 0.5805 - val_y1_output_root_mean_squared_error: 0.4473 - val_y2_output_root_mean_squared_error: 0.7691
# Epoch 481/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3330 - y1_output_loss: 0.1238 - y2_output_loss: 0.2105 - y1_output_root_mean_squared_error: 0.3526 - y2_output_root_mean_squared_error: 0.4568 - val_loss: 0.8260 - val_y1_output_loss: 0.2188 - val_y2_output_loss: 0.6199 - val_y1_output_root_mean_squared_error: 0.4651 - val_y2_output_root_mean_squared_error: 0.7808
# Epoch 482/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4510 - y1_output_loss: 0.1565 - y2_output_loss: 0.2947 - y1_output_root_mean_squared_error: 0.3957 - y2_output_root_mean_squared_error: 0.5427 - val_loss: 1.5803 - val_y1_output_loss: 0.2687 - val_y2_output_loss: 1.2811 - val_y1_output_root_mean_squared_error: 0.5237 - val_y2_output_root_mean_squared_error: 1.1429
# Epoch 483/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4775 - y1_output_loss: 0.1662 - y2_output_loss: 0.3092 - y1_output_root_mean_squared_error: 0.4086 - y2_output_root_mean_squared_error: 0.5573 - val_loss: 0.8474 - val_y1_output_loss: 0.1773 - val_y2_output_loss: 0.6667 - val_y1_output_root_mean_squared_error: 0.4239 - val_y2_output_root_mean_squared_error: 0.8171
# Epoch 484/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3530 - y1_output_loss: 0.1192 - y2_output_loss: 0.2305 - y1_output_root_mean_squared_error: 0.3467 - y2_output_root_mean_squared_error: 0.4825 - val_loss: 0.8909 - val_y1_output_loss: 0.1651 - val_y2_output_loss: 0.7176 - val_y1_output_root_mean_squared_error: 0.4082 - val_y2_output_root_mean_squared_error: 0.8510
# Epoch 485/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4091 - y1_output_loss: 0.1376 - y2_output_loss: 0.2692 - y1_output_root_mean_squared_error: 0.3712 - y2_output_root_mean_squared_error: 0.5208 - val_loss: 0.9184 - val_y1_output_loss: 0.1754 - val_y2_output_loss: 0.7316 - val_y1_output_root_mean_squared_error: 0.4208 - val_y2_output_root_mean_squared_error: 0.8610
# Epoch 486/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3616 - y1_output_loss: 0.1212 - y2_output_loss: 0.2404 - y1_output_root_mean_squared_error: 0.3486 - y2_output_root_mean_squared_error: 0.4900 - val_loss: 0.7196 - val_y1_output_loss: 0.1752 - val_y2_output_loss: 0.5309 - val_y1_output_root_mean_squared_error: 0.4225 - val_y2_output_root_mean_squared_error: 0.7356
# Epoch 487/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3319 - y1_output_loss: 0.1222 - y2_output_loss: 0.2079 - y1_output_root_mean_squared_error: 0.3504 - y2_output_root_mean_squared_error: 0.4573 - val_loss: 0.9915 - val_y1_output_loss: 0.1856 - val_y2_output_loss: 0.7881 - val_y1_output_root_mean_squared_error: 0.4324 - val_y2_output_root_mean_squared_error: 0.8970
# Epoch 488/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5137 - y1_output_loss: 0.1495 - y2_output_loss: 0.3644 - y1_output_root_mean_squared_error: 0.3852 - y2_output_root_mean_squared_error: 0.6044 - val_loss: 0.8668 - val_y1_output_loss: 0.2907 - val_y2_output_loss: 0.5762 - val_y1_output_root_mean_squared_error: 0.5348 - val_y2_output_root_mean_squared_error: 0.7621
# Epoch 489/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3866 - y1_output_loss: 0.1367 - y2_output_loss: 0.2505 - y1_output_root_mean_squared_error: 0.3692 - y2_output_root_mean_squared_error: 0.5003 - val_loss: 1.0037 - val_y1_output_loss: 0.2210 - val_y2_output_loss: 0.7676 - val_y1_output_root_mean_squared_error: 0.4750 - val_y2_output_root_mean_squared_error: 0.8821
# Epoch 490/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4729 - y1_output_loss: 0.1533 - y2_output_loss: 0.3172 - y1_output_root_mean_squared_error: 0.3914 - y2_output_root_mean_squared_error: 0.5654 - val_loss: 0.7996 - val_y1_output_loss: 0.1945 - val_y2_output_loss: 0.5948 - val_y1_output_root_mean_squared_error: 0.4439 - val_y2_output_root_mean_squared_error: 0.7762
# Epoch 491/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4535 - y1_output_loss: 0.1509 - y2_output_loss: 0.2998 - y1_output_root_mean_squared_error: 0.3898 - y2_output_root_mean_squared_error: 0.5491 - val_loss: 0.7638 - val_y1_output_loss: 0.1743 - val_y2_output_loss: 0.5862 - val_y1_output_root_mean_squared_error: 0.4165 - val_y2_output_root_mean_squared_error: 0.7683
# Epoch 492/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3173 - y1_output_loss: 0.1233 - y2_output_loss: 0.1940 - y1_output_root_mean_squared_error: 0.3524 - y2_output_root_mean_squared_error: 0.4394 - val_loss: 1.1712 - val_y1_output_loss: 0.2038 - val_y2_output_loss: 0.9875 - val_y1_output_root_mean_squared_error: 0.4493 - val_y2_output_root_mean_squared_error: 0.9846
# Epoch 493/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4598 - y1_output_loss: 0.1545 - y2_output_loss: 0.3053 - y1_output_root_mean_squared_error: 0.3943 - y2_output_root_mean_squared_error: 0.5516 - val_loss: 0.7563 - val_y1_output_loss: 0.1629 - val_y2_output_loss: 0.5927 - val_y1_output_root_mean_squared_error: 0.4048 - val_y2_output_root_mean_squared_error: 0.7697
# Epoch 494/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3706 - y1_output_loss: 0.1350 - y2_output_loss: 0.2354 - y1_output_root_mean_squared_error: 0.3686 - y2_output_root_mean_squared_error: 0.4845 - val_loss: 0.7266 - val_y1_output_loss: 0.1524 - val_y2_output_loss: 0.5603 - val_y1_output_root_mean_squared_error: 0.3921 - val_y2_output_root_mean_squared_error: 0.7569
# Epoch 495/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3979 - y1_output_loss: 0.1514 - y2_output_loss: 0.2452 - y1_output_root_mean_squared_error: 0.3896 - y2_output_root_mean_squared_error: 0.4961 - val_loss: 0.8493 - val_y1_output_loss: 0.1731 - val_y2_output_loss: 0.6706 - val_y1_output_root_mean_squared_error: 0.4191 - val_y2_output_root_mean_squared_error: 0.8208
# Epoch 496/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.2998 - y1_output_loss: 0.1178 - y2_output_loss: 0.1817 - y1_output_root_mean_squared_error: 0.3431 - y2_output_root_mean_squared_error: 0.4267 - val_loss: 0.7628 - val_y1_output_loss: 0.1858 - val_y2_output_loss: 0.5729 - val_y1_output_root_mean_squared_error: 0.4303 - val_y2_output_root_mean_squared_error: 0.7600
# Epoch 497/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3784 - y1_output_loss: 0.1297 - y2_output_loss: 0.2511 - y1_output_root_mean_squared_error: 0.3596 - y2_output_root_mean_squared_error: 0.4991 - val_loss: 0.8036 - val_y1_output_loss: 0.2166 - val_y2_output_loss: 0.5684 - val_y1_output_root_mean_squared_error: 0.4682 - val_y2_output_root_mean_squared_error: 0.7644
# Epoch 498/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3852 - y1_output_loss: 0.1330 - y2_output_loss: 0.2501 - y1_output_root_mean_squared_error: 0.3655 - y2_output_root_mean_squared_error: 0.5016 - val_loss: 0.9831 - val_y1_output_loss: 0.1871 - val_y2_output_loss: 0.7877 - val_y1_output_root_mean_squared_error: 0.4354 - val_y2_output_root_mean_squared_error: 0.8908
# Epoch 499/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4253 - y1_output_loss: 0.1373 - y2_output_loss: 0.3149 - y1_output_root_mean_squared_error: 0.3711 - y2_output_root_mean_squared_error: 0.5363 - val_loss: 5.2157 - val_y1_output_loss: 0.2450 - val_y2_output_loss: 5.0641 - val_y1_output_root_mean_squared_error: 0.4940 - val_y2_output_root_mean_squared_error: 2.2297
# Epoch 500/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.5443 - y1_output_loss: 0.1351 - y2_output_loss: 0.4061 - y1_output_root_mean_squared_error: 0.3682 - y2_output_root_mean_squared_error: 0.6393 - val_loss: 0.9010 - val_y1_output_loss: 0.1982 - val_y2_output_loss: 0.6862 - val_y1_output_root_mean_squared_error: 0.4482 - val_y2_output_root_mean_squared_error: 0.8368

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 34us/sample - loss: 0.9010 - y1_output_loss: 0.2007 - y2_output_loss: 0.7070 - y1_output_root_mean_squared_error: 0.4482 - y2_output_root_mean_squared_error: 0.8368
# Loss = 0.9010280510047813, Y1_loss = 0.2006814181804657, Y1_mse = 0.44818493723869324, Y2_loss = 0.7069816589355469, Y2_mse = 0.8367546796798706

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
